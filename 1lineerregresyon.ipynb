# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %% [markdown]
# # satır nolarına göre gidişaat açıklaması
# 1- ilk olarak veri setini pd.read_csv("") ile çağrıyoruz
#
# 2- ilk index haricindeki verilerin hepsini kapsattırttırıyoruz ilk indexte index noları kolon olarak yazıldığından ona gerek yok
#
# 3- örnek göseterttirdik

# %%
#1
df=pd.read_csv("Advertising.csv")
#2
df=df.iloc[:,1:len(df)]
#3
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# # Grafik oluşturtturma
# 1- Seaborn kütüphanesini grafik oluşturabilmek için çağrıyoruz
#
# 2- Grafiği oluşturtturtuyoruz

# %%
import seaborn as sns
K=sns.jointplot(x = "TV",y = "sales",data=df,kind="reg")

# %% [markdown]
# # Lineer Tahminlerde Bulundurtma
# * İlk olarak tahmini yaptırtacak modülü çağrıyoruz
# * Sonra X ve Y yi belirtiyoruz ki x e göre y yi tahmin ettiricez
# * --- fit çalışttırtmayı sağlıyor ---
# * ###. dir(model) dediğimizde yapabileceğimiz operasyonları gösterir .###

# %%
from sklearn import linear_model
X=df[["TV"]]
Y=df[["sales"]]
reg=LinearRegression()
model=reg.fit(X,Y)
dir(model)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_data',
#  'coef_',
#  'copy_X',
#  'feature_names_in_',
#  'fit',
#  'fit_intercept',
#  'get_params',
#  'intercept_',
#  'n_features_in_',
#  'n_jobs',
#  'normalize',
#  'positive',
#  'predict',
#  'rank_',
#  'score',
#  'set_params',
# ...

# %% [markdown]
# * dirdeki metodlar için örnek çalışma:

# %%
model.intercept_ #sabit aldırtır ax+c deki c dir
# Out:
# array([7.03259355])

# %%
model.coef_ #beta 1 katsayısı ax+c deki x dir
# Out:
# array([[0.04753664]])

# %%
model.score(X,Y) 
#Yaptığımız model % 60 verileri açıklıyor
# Out:
# 0.611875050850071

# %% [markdown]
# * Bu sayfada tv ve satış arasındaki ilişkiyi öğrendik denklem= 7.03+ TV*0,05 dir
# * Mesela TV= 1 ise satış=7,08 dir
# * Yaptığımız model verilerin %60 nı biliyor

# %%
X.head()
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
turko=pd.concat([y,Y])
print(turko)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\furo\Desktop\öğrenilenler\türkcell eğitimleri\2-türkcell makine öğrenmesi\1lineerregresyon.ipynb Cell 15 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/furo/Desktop/%C3%B6%C4%9Frenilenler/t%C3%BCrkcell%20e%C4%9Fitimleri/2-t%C3%BCrkcell%20makine%20%C3%B6%C4%9Frenmesi/1lineerregresyon.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> turko=pd.concat([y,Y])
#       <a href='vscode-notebook-cell:/c%3A/Users/furo/Desktop/%C3%B6%C4%9Frenilenler/t%C3%BCrkcell%20e%C4%9Fitimleri/2-t%C3%BCrkcell%20makine%20%C3%B6%C4%9Frenmesi/1lineerregresyon.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> print(turko)
#
# NameError: name 'y' is not defined
